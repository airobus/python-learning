# %%
# !pip install chainlit
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 1.2 MB/s eta 0:00:0000:0100:010m
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/20/f7/b24208eba89f9d1b58c1668bc6c8c4fd472b20c45573cb767f59d49fb0f6/numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/3d/47/444768600d9e0ebc82f8e347775d24aef8f6348cf00e9fa0e81910814e6d/python_multipart-0.0.9-py3-none-any.whl (22 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 4.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...

# %%
# chainlit run app.py -w ：-w 热加载
# !chainlit run app.py -w
# !chainlit run pdfqa.py -w
# Out:
# 2024-07-10 09:41:37 - Your app is available at http://localhost:8000
# 2024-07-10 09:41:39 - Translation file for zh-CN not found. Using default translation en-US.
# 2024-07-10 09:41:39 - Translated markdown file for zh-CN not found. Defaulting to chainlit.md.
# 2024-07-10 09:41:59 - Translation file for zh-CN not found. Using default translation en-US.
# 2024-07-10 09:43:16 - 3 changes detected
# 2024-07-10 09:43:24 - Translation file for zh-CN not found. Using default translation en-US.
# 2024-07-10 09:43:26 - Translation file for zh-CN not found. Using default translation en-US.
# 2024-07-10 09:43:28 - process_response() missing 1 required positional argument: 'res'
# Traceback (most recent call last):
#   File "/Users/pangmengting/venv/lib/python3.10/site-packages/chainlit/utils.py", line 44, in wrapper
#     return await user_function(**params_values)
# TypeError: process_response() missing 1 required positional argument: 'res'
# ...
