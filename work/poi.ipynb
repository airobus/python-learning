# %%
import requests
from bs4 import BeautifulSoup

url = "http://www.dianping.com/hangzhou/ch10/p2"
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

# Navigate to the desired container
container = soup.find('div', {'class': 'section Fix J-shop-search'})
content_wrap = container.find('div', {'class': 'content-wrap'})
shop_wrap = content_wrap.find('div', {'class': 'shop-wrap'})
content = shop_wrap.find('div', {'class': 'content'})
shop_all_list = content.find('div', {'id': 'shop-all-list'})

# Find the <ul> element
ul_element = shop_all_list.find('ul')

# Extract the <li> elements
li_elements = ul_element.find_all('li')

# Loop through the <li> elements and extract the data
for li in li_elements:
    # Extract the shop name
    shop_name = li.find('h4').text.strip()
    # Extract the shop address
    shop_address = li.find('span', {'class': 'addr'}).text.strip()
    # Extract the shop rating
    shop_rating = li.find('span', {'class': 'rating'}).text.strip()
    # Print the extracted data
    print(f"Shop Name: {shop_name}, Address: {shop_address}, Rating: {shop_rating}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 10
#       8 # Navigate to the desired container
#       9 container = soup.find('div', {'class': 'section Fix J-shop-search'})
# ---> 10 content_wrap = container.find('div', {'class': 'content-wrap'})
#      11 shop_wrap = content_wrap.find('div', {'class': 'shop-wrap'})
#      12 content = shop_wrap.find('div', {'class': 'content'})
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
# Out:
# <!DOCTYPE html>
# <html><head><meta charset="utf-8"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="noindex, nofollow" name="robots"/><meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no,minimal-ui" name="viewport"/><title>携程旅行网</title><style type="text/css">blockquote,body,button,code,dd,div,dl,dt,em,fieldset,form,h1,h2,h3,h4,h5,h6,html,input,legend,li,ol,p,pre,td,textarea,th,ul{margin:0;padding:0}body{font-size:12px;font-family:Simsun,sans-serif;color:#333}fieldset,img{border:0 none}input,textarea{font-size:12px}textarea{resize:none}table{border-collapse:collapse;border-spacing:0}a{color:#003d7e;text-decoration:none}a:hover{text-decoration:underline}h1,h2,h3,h4,h5,h6{font-family:"Times New Roman",Simsun}li,ol,ul{list-style:none outside none}dfn{font-style:normal}@media screen and (min-width:751px){#footer,.content,.errorinfo{width:800px}.wrap{background:#016eca;width:100%;min-width:1200px;overflow:hidden}.content{position:relative;z-index:1;height:480px;margin:0 auto;padding-top:100px}.logo{position:relative;z-index:5;width:144px;height:54px;margin:0 auto;overflow:hidden;text-indent:-500px;background-position:0 0}.errorinfo{color:#fff;display:block;font-family:"microsoft yahei",simhei,sans-serif;font-size:24px;font-weight:400;text-align:center;margin:30px auto;padding:0}a.goback{display:block;position:relative;z-index:4;width:112px;margin:20px auto;padding:8px 0;color:#fff;font-family:"microsoft yahei",simhei,sans-serif;font-size:16px;text-align:center;text-decoration:none;background-color:#0f4dc5}a.goback:hover{background-color:#3f92f0}.tower{position:absolute;transform:translateZ(300px);z-index:2;top:143px;left:291px;width:116px;height:264px;background:url(https://webresource.c-ctrip.com/ares2/nfes/pc-home/*/default/others/tower.png) no-repeat}.beam{position:absolute;z-index:1;left:-10px;top:0;width:749px;height:359px;background:url(https://webresource.c-ctrip.com/ares2/nfes/pc-home/*/default/others/light.png) no-repeat;-webkit-animation:6s cubic-bezier(.25,0,.75,1) 0s none infinite beam;-moz-animation:6s cubic-bezier(.25,0,.75,1) 0s none infinite beam;animation:6s cubic-bezier(.25,0,.75,1) 0s none infinite beam}.wave1{position:absolute;z-index:99;top:400px;height:180px;width:1200px;left:0;right:0;margin:auto;opacity:0;background:url(https://webresource.c-ctrip.com/ares2/nfes/pc-home/*/default/others/wave.png) repeat-x 0 0;-webkit-animation:50s linear 0s none infinite tweenxxpc;-moz-animation:50s linear 0s none infinite tweenxxpc;animation:50s linear 0s none infinite tweenxxpc}.wave{position:absolute;z-index:100;top:400px;height:180px;width:1200px;left:0;right:0;margin:auto;background:url(https://webresource.c-ctrip.com/ares2/nfes/pc-home/*/default/others/wave.png) repeat-x 0 0;-webkit-animation:50s linear 0s none infinite tweenxpc;-moz-animation:50s linear 0s none infinite tweenxpc;animation:50s linear 0s none infinite tweenxpc}#footer{margin:0 auto;text-align:center;color:#0053aa;font-family:arial;line-height:1.6;padding:8px 0 0 0;width:1200px}#footer a{color:#0053aa}.copyright{color:#333}.star1{background:url(https://webresource.c-ctrip.com/ares2/nfes/pc-home/*/default/others/star.png) no-repeat;position:relative;top:164px;left:592px;height:60px;width:60px;opacity:0;-webkit-animation:2s linear 0s none infinite staracta;-moz-animation:2s linear 0s none infinite staracta;animation:2s linear 0s none infinite staracta}.star2{background:url(https://webresource.c-ctrip.com/ares2/nfes/pc-home/*/default/others/star.png) no-repeat;position:relative;top:234px;left:245px;height:60px;width:60px;opacity:.8;-webkit-animation:2s linear 0s none infinite staract;-moz-animation:2s linear 0s none infinite staract;animation:2s linear 0s none infinite staract}.star3{background:url(https://webresource.c-ctrip.com/ares2/nfes/pc-home/*/default/others/star.png) no-repeat;position:relative;top:252px;left:644px;height:60px;width:60px;opacity:.8;-webkit-animation:2s linear 0s none infinite staract;-moz-animation:2 ...

# %%
import requests


def get_restaurant_data(url):
    payload = {}
    headers = {
        'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
        'accept-language': 'zh-CN,zh;q=0.9',
        'cookie': 'ASP.NET_SessionSvc=MTAuMTEzLjkyLjg2fDkwOTB8b3V5YW5nfGRlZmF1bHR8MTYzODQzMzkyNzYwMA; MKT_CKID=1715932998137.di2aa.00zw; _RF1=218.75.127.235; _RSG=qW4oYxCO0I8dYil6r2tMAB; _RDG=28ebc0d51b160d221122ea3c9a5f590680; _RGUID=848060ce-e2c8-4834-b296-dc2d46bec8a7; GUID=09031170315935642625; _bfaStatusPVSend=1; Hm_lvt_e4211314613fcf074540918eb10eeecb=1715933140; _bfa=1.1715932996674.2b9vyo.1.1716356706201.1716356761442.5.5.154019; _ubtstatus=%7B%22vid%22%3A%221715932996674.2b9vyo%22%2C%22sid%22%3A5%2C%22pvid%22%3A5%2C%22pid%22%3A154019%7D; _jzqco=%7C%7C%7C%7C1716350340496%7C1.291136378.1715932998127.1716356221356.1716356768397.1716356221356.1716356768397.0.0.0.16.16; _bfi=p1%3D154019%26p2%3D154019%26v1%3D5%26v2%3D4; _bfaStatus=success; Hm_lpvt_e4211314613fcf074540918eb10eeecb=1716356803',
        'priority': 'u=0, i',
        'referer': 'https://you.ctrip.com/restaurantlist/Hangzhou14/list-x415-c4931-p1.html?ordertype=0',
        'sec-ch-ua': '"Chromium";v="124", "Microsoft Edge";v="124", "Not-A.Brand";v="99"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'document',
        'sec-fetch-mode': 'navigate',
        'sec-fetch-site': 'same-origin',
        'sec-fetch-user': '?1',
        'upgrade-insecure-requests': '1',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36 Edg/124.0.0.0'
    }

    response = requests.request("GET", url, headers=headers, data=payload)

    # print(response.text)
    return response

# %%
from bs4 import BeautifulSoup


def handle_data(response):
    soup = BeautifulSoup(response.content, 'html.parser')
    hp_container = soup.find('div', {'id': 'hp_container'})
    content = hp_container.find('div', {'id': 'content'})
    ttd2_background = content.find('div', {'class': 'ttd2_background'})
    content_cf = ttd2_background.find('div', {'class': 'content cf'})
    des_wide_f_right = content_cf.find('div', {'class': 'des_wide f_right'})
    normalbox = des_wide_f_right.find('div', {'class': 'normalbox'})
    list_wide_mod2 = normalbox.find('div', {'class': 'list_wide_mod2'})
    return list_wide_mod2

# %%
def get_list_wide_mod2(list_wide_mod2):
    list_mod2s = list_wide_mod2.find_all('div', {'class': 'list_mod2'})
    return list_mod2s

# %%
def get_end_data(list_mod2s):
    results = []
    for li in list_mod2s:
        leftimg = li.find('div', {'class': 'leftimg'})
        img_a_tag = leftimg.find('a')
        img = leftimg.find('img')
        img_url = img.get('data-imgurl')
        # print(img_url)

        rdetailbox = li.find('div', {'class': 'rdetailbox'})
        dl = rdetailbox.find('dl')
        dt = dl.find('dt')
        a = dt.find('a')
        title = a.get('title')
        print(title)

        address = dl.find('dd').text.strip()
        # print(address)

        results.append({
            'img_url': img_url,
            'title': title,
            'address': address
        })
        print('-----------------------')
    return results

# %%
def do_http(url):
    response = get_restaurant_data(url)
    return response

# %%
def do_data(response):
    # 数据处理
    list_wide_mod2 = handle_data(response)
    list_mod2s = get_list_wide_mod2(list_wide_mod2)
    results = get_end_data(list_mod2s)
    return results

# %%
def append_write(results, file_name):
    file_data = []

    for data_item in results:
        img_url = data_item['img_url'].replace("'", "").replace("\"", "")
        title = data_item['title'].replace("'", "").replace("\"", "")
        address = data_item['address'].replace("'", "").replace("\"", "")

        output_string = f"图片:[\"{img_url}\"];标题:[\"{title}\"];地址:[\"{address}\"] \n"
        file_data.append(output_string)

    # 'w' 表示写入模式，会覆盖文件内容。
    # 'a' 表示追加模式，会在文件末尾追加内容。
    with open(file_name, 'a', encoding='utf-8') as f:
        f.write(''.join(file_data))

# %%
import time
import random

# 定义 URL 列表
# urls = [
#     "https://you.ctrip.com/restaurantlist/hangzhou14/s4901-r410-p7.html",
# ]

# 西湖区-快餐简餐
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4901-r410-p{}.html"
# 拱墅区-江浙菜
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4897-r411-p{}.html"
# 上城区-面包甜点
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4902-r408-p{}.html"
# 滨江-烧烤
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4931-r413-p{}.html"
# 滨江-火锅
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4903-r413-p{}.html"
# 余杭-烧烤
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4931-r415-p{}.html"
# 余杭-自助餐
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4936-r415-p{}.html"
# 余杭-韩国料理
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4905-r415-p{}.html"
# 余杭-东北菜
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4924-r415-p{}.html"
# 余杭-海鲜
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4934-r415-p{}.html"
# 余杭-粤菜
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4898-r415-p{}.html"
# 临安-快餐简餐
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4901-r685330-p{}.html"
# 临安-江浙菜
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4897-r685330-p{}.html"
# 临安-川菜
# base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4896-r685330-p{}.html"
# 临安-农家菜
base_url = "https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p{}.html"

file_name = "临安-农家菜.txt"
# 左闭右开
urls = [base_url.format(p) for p in range(1, 38)]

# 循环执行
for index, url in enumerate(urls, start=1):
    print(f">>>>>>第{index}批,开始,url:{url}")
    response = do_http(url)
    results = do_data(response)
    append_write(results, file_name)
    # 暂停 X 秒
    sleep_time = random.uniform(10, 20)
    print(f"sleep_time: {sleep_time}")
    time.sleep(sleep_time)
# Out:
# >>>>>>第1批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p1.html
# 東大方(临安城中街店)
# -----------------------
# 地锅即递(临天路二店)
# -----------------------
# 大明山山沟沟农家菜(大大线店)
# -----------------------
# 龙潭甲鱼山庄
# -----------------------
# 老地方土家菜(湍泉街店)
# -----------------------
# 丽景餐厅(湍泉路店)
# -----------------------
# 天目山甲鱼农庄
# -----------------------
# 天目一号山里人家(藻天线店)
# -----------------------
# 大明山相遇农家
# -----------------------
# 龙井源山庄餐厅
# -----------------------
# 响板石农庄
# -----------------------
# 柳栖民宿私房菜(河桥古镇店)
# -----------------------
# 天目山庄餐厅
# -----------------------
# 森竹园农庄
# -----------------------
# 随变吃柴神鱼(青山湖景区店)
# -----------------------
# sleep_time: 12.981677314281841
# >>>>>>第2批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p2.html
# 杭州又见民宿·餐厅
# -----------------------
# 隐田雅居(天目山民宿学院店)·餐厅
# -----------------------
# 湍口光头家乡菜馆
# -----------------------
# 青山湖野鱼馆
# -----------------------
# 西天目山胡家大院农家乐
# -----------------------
# 西天目林海农庄
# -----------------------
# 大明山望山农家乐
# -----------------------
# 盈客居农庄
# -----------------------
# 马啸家乡菜(六园街店)
# -----------------------
# 忆家土菜馆
# -----------------------
# 余村农家
# -----------------------
# 杭州潜南农家乐餐厅
# -----------------------
# 临安神农仙居(太湖源店)
# -----------------------
# 剑门酒家
# -----------------------
# 华丽农家乐
# -----------------------
# sleep_time: 18.41183499224924
# >>>>>>第3批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p3.html
# 好运来饭店(浮玉路店)
# -----------------------
# 马溪人家土菜馆
# -----------------------
# 田景轩农家乐
# -----------------------
# 沈家大院
# -----------------------
# 指南村农家乐
# -----------------------
# 湍口人家
# -----------------------
# 益红酒家(玲珑山店)
# -----------------------
# 云松人家
# -----------------------
# 大明山水缘
# -----------------------
# 胡氏农庄
# -----------------------
# 临安林家塘丛林农家
# -----------------------
# 峡谷餐厅(浙西大峡谷店)
# -----------------------
# 农家老铺
# -----------------------
# 云中菜馆·香樟树(玲珑店)
# -----------------------
# 天目山孙越农庄
# -----------------------
# sleep_time: 16.416573501258085
# >>>>>>第4批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p4.html
# 东婷家园
# -----------------------
# 风门农家
# -----------------------
# 天赐农庄
# -----------------------
# 潘园云漫·红枫名宿
# -----------------------
# 开心农家
# -----------------------
# 天目山一口天酒家
# -----------------------
# 杭州临安浪源客栈·临安小卫土菜馆
# -----------------------
# 杭州临安夏尔民宿·餐厅
# -----------------------
# 菜园农家乐
# -----------------------
# 地锅即递(石镜街1店)
# -----------------------
# 来来往往餐厅
# -----------------------
# 忆湍味餐厅
# -----------------------
# 雅庄农家
# -----------------------
# 原味家
# -----------------------
# 乡舍农家
# -----------------------
# sleep_time: 16.368257342862915
# >>>>>>第5批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p5.html
# 银杏酒家
# -----------------------
# 大龙湾农庄郑丽农家乐
# -----------------------
# 临安竹里馆农庄
# -----------------------
# 一都小吃农家菜(门西线店)
# -----------------------
# 斐文野奢酒店·私房菜·轻吧
# -----------------------
# 寻味轩(水南村综合大楼店)
# -----------------------
# 杭昌土菜馆
# -----------------------
# 望景农居-餐饮
# -----------------------
# 山水湾牛肉馆
# -----------------------
# 乡村土菜馆(万牧线店)
# -----------------------
# 饭家灯火
# -----------------------
# 民惠土菜馆
# -----------------------
# 和旺农庄
# -----------------------
# 大自然饭店(永丰路店)
# -----------------------
# 水上楼阁
# -----------------------
# sleep_time: 19.485010719831248
# >>>>>>第6批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p6.html
# 五谷丰登土菜馆
# -----------------------
# 吴狄土鸡(临安总店)
# -----------------------
# 小菜一碟(唐昌街店)
# -----------------------
# 地锅水浒(醉花路店)
# -----------------------
# 鹿鸣宴
# -----------------------
# 九仙农家
# -----------------------
# 阿亲嫂酒家
# -----------------------
# 竹乡农家
# -----------------------
# 驿吱鸟土菜馆
# -----------------------
# 龙井山庄餐厅
# -----------------------
# 拉斯维加斯餐厅(天目山店)
# -----------------------
# 家乡人农家菜(石镜街店)
# -----------------------
# 铁锅年代(锦江路店)
# -----------------------
# 农家菜馆
# -----------------------
# 常尝乐农家菜
# -----------------------
# sleep_time: 14.563249380098448
# >>>>>>第7批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p7.html
# 竹林农家
# -----------------------
# 鱼米之乡
# -----------------------
# 地锅即递(青山店)
# -----------------------
# 地锅传奇(临安店)
# -----------------------
# 朱直坞农庄
# -----------------------
# 红墙门乡土菜
# -----------------------
# 大明山柳玲农家
# -----------------------
# 黄小厨土菜馆
# -----------------------
# 阿娟面馆土菜馆(唐昌街266号店)
# -----------------------
# 农家饭店(青溪街店)
# -----------------------
# 小乐惠土菜馆(龙岗店)
# -----------------------
# 青云农家
# -----------------------
# 骆口味农家菜
# -----------------------
# 衢味轩农家菜(青山星悦城店)
# -----------------------
# 杭州临安翡翠谷农家乐(横乐线分店)
# -----------------------
# sleep_time: 16.592212079221873
# >>>>>>第8批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p8.html
# 胡家大院
# -----------------------
# 柳栖民宿私房菜(河桥古镇店)
# -----------------------
# 地锅鸡农家大灶台
# -----------------------
# 临安农夫土菜馆农家乐
# -----------------------
# 临安太湖源红叶农家
# -----------------------
# 马啸人家土菜馆
# -----------------------
# 百姓餐馆
# -----------------------
# 康乐农家
# -----------------------
# 瑞城农庄
# -----------------------
# 林氏农家
# -----------------------
# 指南村张家泉农家
# -----------------------
# 临溪土菜馆(临安店)
# -----------------------
# 余杭佬土菜馆
# -----------------------
# 阿龙土菜馆
# -----------------------
# 惠聚春秋农家小院(西墅街店)
# -----------------------
# sleep_time: 18.48524246594866
# >>>>>>第9批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p9.html
# 东天目农家小院
# -----------------------
# 独山渔家农家乐
# -----------------------
# 奚氏山庄农家乐
# -----------------------
# 浙川车站农家
# -----------------------
# 天目农家
# -----------------------
# 杭州临安望川阁客栈
# -----------------------
# 朴宿·8号
# -----------------------
# 三松农家菜馆
# -----------------------
# 玖玖93农庄
# -----------------------
# 老董农家
# -----------------------
# 里仁农家(里仁饭店)
# -----------------------
# 青枫农家
# -----------------------
# 薇薇溪水农家乐
# -----------------------
# 席家菜馆(碧桂苑店)
# -----------------------
# 马哥农家
# -----------------------
# sleep_time: 12.68438154158564
# >>>>>>第10批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p10.html
# 忠孝土菜馆
# -----------------------
# 哈妮农家乐(地龙线店)
# -----------------------
# 缘食斋
# -----------------------
# 梦香农家(天目山店)
# -----------------------
# 阿炮土菜馆
# -----------------------
# 双塔土菜馆
# -----------------------
# 乡里香农家菜
# -----------------------
# 姐妹农家
# -----------------------
# 力嫂农家
# -----------------------
# 膳王甲(新民街店)
# -----------------------
# 海龙土菜馆(大桥北路店)
# -----------------------
# 竹缘山庄农家乐
# -----------------------
# 人缘农家
# -----------------------
# 强哥土菜馆
# -----------------------
# 文谦土菜馆
# -----------------------
# sleep_time: 11.807850882068717
# >>>>>>第11批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p11.html
# 朋友家土菜馆
# -----------------------
# 吉祥饭店土菜馆
# -----------------------
# 小米家•遇见你(农家菜•秘制烧烤)
# -----------------------
# 倪好农庄
# -----------------------
# 红林度假山庄餐厅
# -----------------------
# 新溪土菜馆
# -----------------------
# 爱仙农家乐
# -----------------------
# 千家灶农家乐
# -----------------------
# 小俩口土菜馆
# -----------------------
# 笑笑农家
# -----------------------
# 章记土菜馆(景杉路店)
# -----------------------
# 赣湘风味土菜馆
# -----------------------
# 山坞里土菜馆
# -----------------------
# 翠娟农庄(横畈镇店)
# -----------------------
# 羊村大院(圣园路店)
# -----------------------
# sleep_time: 10.916559757862569
# >>>>>>第12批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p12.html
# 袁氏烤鸡
# -----------------------
# 地锅基地(万马路店)
# -----------------------
# 乐平土菜馆(锦胜小区店)
# -----------------------
# 农家小厨野菜馆(东塔街店)
# -----------------------
# 竹园农家
# -----------------------
# 昌化土菜馆
# -----------------------
# 麒麟山庄
# -----------------------
# 杭州美珍农家乐
# -----------------------
# 葡萄园农庄
# -----------------------
# 云溪山庄
# -----------------------
# 小徐菜馆
# -----------------------
# 冰川大峡谷农庄
# -----------------------
# 石良农家
# -----------------------
# 长廊农家
# -----------------------
# 溪缘农家
# -----------------------
# sleep_time: 10.463645283042633
# >>>>>>第13批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p13.html
# 临安市云顶农家乐
# -----------------------
# 浙西农家
# -----------------------
# 山旺农家
# -----------------------
# 志伟厨房
# -----------------------
# 小豹饭店
# -----------------------
# 溪畔原香菜馆
# -----------------------
# 临安爱月农家
# -----------------------
# 来相聚土菜馆
# -----------------------
# 阿翘农家菜馆
# -----------------------
# 临安王家土菜馆
# -----------------------
# 玉花土菜馆
# -----------------------
# 童家厨房
# -----------------------
# 洪海土菜馆
# -----------------------
# 农家土菜
# -----------------------
# 飘香鱼土菜馆
# -----------------------
# sleep_time: 15.8542952090534
# >>>>>>第14批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p14.html
# 三家村
# -----------------------
# 太湖源随缘农家
# -----------------------
# 醉红土菜馆(碧桂苑二区店)
# -----------------------
# 横路土菜馆
# -----------------------
# 盛世人家
# -----------------------
# sleep_time: 14.588861454613854
# >>>>>>第15批,开始,url:https://you.ctrip.com/restaurantlist/hangzhou14/s4910-r685330-p15.html
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 48
#      46 print(f">>>>>>第{index}批,开始,url:{url}")
#      47 response = do_http(url)
# ---> 48 results = do_data(response)
#      49 append_write(results, file_name)
#      50 # 暂停 X 秒
#
# Cell In[7], line 4, in do_data(response)
#       1 def do_data(response):
#       2     # 数据处理
#       3     list_wide_mod2 = handle_data(response)
# ----> 4     list_mod2s = get_list_wide_mod2(list_wide_mod2)
#       5     results = get_end_data(list_mod2s)
#       6     return results
#
# Cell In[4], line 2, in get_list_wide_mod2(list_wide_mod2)
#       1 def get_list_wide_mod2(list_wide_mod2):
# ----> 2     list_mod2s = list_wide_mod2.find_all('div', {'class': 'list_mod2'})
#       3     return list_mod2s
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
