# %%
import requests
from bs4 import BeautifulSoup
import re
import time


class WebCrawler:
    def __init__(self, url, max_depth=1, max_pages=100):
        self.url = url
        self.max_depth = max_depth
        self.max_pages = max_pages
        self.visited = set()
        self.pages = []

    def crawl(self):
        self.pages.append(self.url)
        self.visited.add(self.url)

        while self.pages and len(self.pages) <= self.max_pages:
            current_page = self.pages.pop(0)
            print(f"Crawling: {current_page}")

            try:
                response = requests.get(current_page)
                response.raise_for_status()

                soup = BeautifulSoup(response.content, 'html.parser')

                for link in soup.find_all('a', href=True):
                    href = link['href']

                    if href.startswith('http'):
                        href = re.sub(r'^https?://', '', href)

                    if href not in self.visited and href not in self.pages:
                        self.pages.append(href)
                        self.visited.add(href)

                        if self.max_depth > 0:
                            self.crawl()

            except requests.exceptions.RequestException as e:
                print(f"Error: {e}")

    def get_feed(self):
        feed = []
        for page in self.pages:
            response = requests.get(page)
            response.raise_for_status()

            soup = BeautifulSoup(response.content, 'html.parser')

            for title in soup.find_all('title'):
                feed.append(title.text)

        return feed


crawler = WebCrawler(url='https://blog.funning.top/article/112250.html',
                     max_depth=2,
                     max_pages=50)
crawler.crawl()

feed = crawler.get_feed()
print(feed)
# Out:
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: v1.funning.top/
# Error: Invalid URL 'v1.funning.top/': No scheme supplied. Perhaps you meant https://v1.funning.top/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: funning.x10.mx
# Error: Invalid URL 'funning.x10.mx': No scheme supplied. Perhaps you meant https://funning.x10.mx?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: hot.funning.top/
# Error: Invalid URL 'hot.funning.top/': No scheme supplied. Perhaps you meant https://hot.funning.top/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: gemini.funning.top/
# Error: Invalid URL 'gemini.funning.top/': No scheme supplied. Perhaps you meant https://gemini.funning.top/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: lobe-chat.funning.top/
# Error: Invalid URL 'lobe-chat.funning.top/': No scheme supplied. Perhaps you meant https://lobe-chat.funning.top/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: chat.funning.top
# Error: Invalid URL 'chat.funning.top': No scheme supplied. Perhaps you meant https://chat.funning.top?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: tool.funning.top/
# Error: Invalid URL 'tool.funning.top/': No scheme supplied. Perhaps you meant https://tool.funning.top/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /
# Error: Invalid URL '/': No scheme supplied. Perhaps you meant https:///?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: javascript:anzhiyu.scrollToDest(0, 500)
# Error: No connection adapters were found for 'javascript:anzhiyu.scrollToDest(0, 500)'
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: javascript:void(0);
# Error: No connection adapters were found for 'javascript:void(0);'
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /archives/
# Error: Invalid URL '/archives/': No scheme supplied. Perhaps you meant https:///archives/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /categories/
# Error: Invalid URL '/categories/': No scheme supplied. Perhaps you meant https:///categories/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/
# Error: Invalid URL '/tags/': No scheme supplied. Perhaps you meant https:///tags/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /link/
# Error: Invalid URL '/link/': No scheme supplied. Perhaps you meant https:///link/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /fcircle/
# Error: Invalid URL '/fcircle/': No scheme supplied. Perhaps you meant https:///fcircle/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /comments/
# Error: Invalid URL '/comments/': No scheme supplied. Perhaps you meant https:///comments/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /music/
# Error: Invalid URL '/music/': No scheme supplied. Perhaps you meant https:///music/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /bangumis/
# Error: Invalid URL '/bangumis/': No scheme supplied. Perhaps you meant https:///bangumis/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /movies/
# Error: Invalid URL '/movies/': No scheme supplied. Perhaps you meant https:///movies/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /album/
# Error: Invalid URL '/album/': No scheme supplied. Perhaps you meant https:///album/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /about/
# Error: Invalid URL '/about/': No scheme supplied. Perhaps you meant https:///about/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /essay/
# Error: Invalid URL '/essay/': No scheme supplied. Perhaps you meant https:///essay/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: javascript:toRandomPost()
# Error: No connection adapters were found for 'javascript:toRandomPost()'
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /img/wechat.png
# Error: Invalid URL '/img/wechat.png': No scheme supplied. Perhaps you meant https:///img/wechat.png?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /img/alipay.png
# Error: Invalid URL '/img/alipay.png': No scheme supplied. Perhaps you meant https:///img/alipay.png?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/AI/
# Error: Invalid URL '/tags/AI/': No scheme supplied. Perhaps you meant https:///tags/AI/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/Java-IO/
# Error: Invalid URL '/tags/Java-IO/': No scheme supplied. Perhaps you meant https:///tags/Java-IO/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/LLM/
# Error: Invalid URL '/tags/LLM/': No scheme supplied. Perhaps you meant https:///tags/LLM/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/LangChain/
# Error: Invalid URL '/tags/LangChain/': No scheme supplied. Perhaps you meant https:///tags/LangChain/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/MoonshotAI/
# Error: Invalid URL '/tags/MoonshotAI/': No scheme supplied. Perhaps you meant https:///tags/MoonshotAI/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/Nginx/
# Error: Invalid URL '/tags/Nginx/': No scheme supplied. Perhaps you meant https:///tags/Nginx/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/RAG/
# Error: Invalid URL '/tags/RAG/': No scheme supplied. Perhaps you meant https:///tags/RAG/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/SpringBoot/
# Error: Invalid URL '/tags/SpringBoot/': No scheme supplied. Perhaps you meant https:///tags/SpringBoot/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/Vue/
# Error: Invalid URL '/tags/Vue/': No scheme supplied. Perhaps you meant https:///tags/Vue/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/ZooKeeper/
# Error: Invalid URL '/tags/ZooKeeper/': No scheme supplied. Perhaps you meant https:///tags/ZooKeeper/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/aop/
# Error: Invalid URL '/tags/aop/': No scheme supplied. Perhaps you meant https:///tags/aop/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/chain/
# Error: Invalid URL '/tags/chain/': No scheme supplied. Perhaps you meant https:///tags/chain/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/chat/
# Error: Invalid URL '/tags/chat/': No scheme supplied. Perhaps you meant https:///tags/chat/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/chatgpt/
# Error: Invalid URL '/tags/chatgpt/': No scheme supplied. Perhaps you meant https:///tags/chatgpt/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/gpt-3-5/
# Error: Invalid URL '/tags/gpt-3-5/': No scheme supplied. Perhaps you meant https:///tags/gpt-3-5/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/gpt-4/
# Error: Invalid URL '/tags/gpt-4/': No scheme supplied. Perhaps you meant https:///tags/gpt-4/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/java8/
# Error: Invalid URL '/tags/java8/': No scheme supplied. Perhaps you meant https:///tags/java8/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/kimi/
# Error: Invalid URL '/tags/kimi/': No scheme supplied. Perhaps you meant https:///tags/kimi/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/prompt/
# Error: Invalid URL '/tags/prompt/': No scheme supplied. Perhaps you meant https:///tags/prompt/?
# Crawling: https://blog.funning.top/article/112250.html
# Crawling: /tags/%E5