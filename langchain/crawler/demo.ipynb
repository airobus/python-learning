# %%
format = """
{
  "type": "object",
  "properties": {
    "产品名称": {
      "type": "string"
    },
    "价格": {
      "type": "object",
      "properties": {
        "成人": {
          "type": "string"
        },
        "儿童": {
          "type": "string"
        }
      }
    },
    "游玩的天数": {
      "type": "string"
    },
    "描述": {
      "type": "string"
    },
    "产品特色": {
      "type": "string"
    },
    "出发地": {
      "type": "string"
    },
    "行程套餐的名称": {
      "type": "string"
    },
    "批次套餐的名称": {
      "type": "string"
    },
    "标签": {
      "type": "string"
    },
    "每个批次日期对应的价格": {
      "type": "array",
      "items": {
        "type": "object",
        "properties": {
          "日期和价格": {
            "type": "object",
            "properties": {
              "日期": {
                "type": "string"
              },
              "价格": {
                "type": "string"
              }
            }
          }
        }
      },
      "properties": {}
    },
    "活动亮点": {
      "type": "string"
    },
    "每日的具体行程": {
      "type": "string"
    },
    "费用说明": {
      "type": "string"
    },
    "活动说明": {
      "type": "string"
    }
  }
}
"""
