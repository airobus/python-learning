# %%
from langchain_openai import ChatOpenAI
import os
from dotenv import load_dotenv
from langchain_community.embeddings.cloudflare_workersai import CloudflareWorkersAIEmbeddings
from supabase.client import Client, create_client
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import SupabaseVectorStore
from langchain_community.document_loaders import (
    DirectoryLoader,
    UnstructuredMarkdownLoader,
    JSONLoader
)

# %%
load_dotenv(override=True)

qw_llm_openai = ChatOpenAI(
    openai_api_base=os.getenv('DASHSCOPE_API_BASE'),
    openai_api_key=os.getenv('DASHSCOPE_API_KEY'),
    model_name="qwen2-1.5b-instruct",
    temperature=0.7,
    streaming=True,
)
embeddings = CloudflareWorkersAIEmbeddings(
    account_id=os.getenv('CF_ACCOUNT_ID'),
    api_token=os.getenv('CF_API_TOKEN'),
    model_name="@cf/baai/bge-small-en-v1.5",
)

supabase_url = os.environ.get("SUPABASE_URL")
supabase_key = os.environ.get("SUPABASE_SERVICE_KEY")

supabase: Client = create_client(supabase_url, supabase_key)

# %%
import json

# 读取文件内容
with open('../../../file/yxk-list.json', 'r', encoding='utf-8') as f:
    content = f.read()

# 手动解码Unicode字符
decoded_content = content.encode('utf-8').decode('unicode_escape')

# 将解码后的内容转换为JSON对象
data = json.loads(decoded_content)

# 打印或进一步处理data
print(data)
# Out:
# [{'tour_name': 'å©ºæº\x90æ\x99¯å¾·é\x95\x874æ\x97¥ä»\x8eå\x8f¤å¾½å·\x9eå\x88°ç\x93·é\x83½ç\x9a\x84å\x8f\x91ç\x8e°ä¹\x8bæ\x97\x85', 'price': {'adult': 2180, 'child': 880}, 'highlights': ['æ\x96\x87å\x8c\x96å\x8e\x86å\x8f²', 'æ\x87\x92äººæ\x85¢æ¸¸', 'æ¸¸å±±ç\x8e©æ°´'], 'attractions': ['å©ºæº\x90å\x8f¤æ\x9d\x91', 'å\x8f¤å¾½å·\x9e', 'æ\x99¯å¾·é\x95\x87', 'å\x8d\x83å¹´å\x8f¤çª\x91', 'ç\x93·å\x99¨é\x9b\x86å¸\x82'], 'departure_dates': ['2024-10-03', '2024-10-04'], 'departure_city': 'æ\x9d\xadå·\x9e', 'duration': '4å¤©3æ\x99\x9a', 'flight_info': 'æ\x94¯æ\x8c\x81è\x88ªç\x8f\xadå\x8f\x98æ\x9b´è°\x83æ\x95´', 'included_fees': ['äº¤é\x80\x9a', 'ä½\x8få®¿', 'é¤\x90é£\x9f', 'æ\x99¯ç\x82¹é\x97¨ç¥¨'], 'excluded_fees': ['ç§\x81äººæ¶\x88è´¹', 'æ\x97\x85æ¸¸ä¿\x9dé\x99©'], 'notes': 'å»ºè®®æ\x8f\x90å\x89\x8d3-5å¤©æ\x8a¥å\x90\x8d', 'product_manager_speech': {'title': 'æ¸¸å®¢æ·±å\x85¥æ\x96\x87æ\x97\x85è¡\x8c', 'description': 'é\x82£äº\x9bæ\x97\x85è¡\x8cä¸\xadæ\x8e¢ç\x9f¥å\x88°ç\x9a\x84é²\x9cæ´»æ\x96\x87å\x8c\x96ï¼\x8cè§¦è¾¾å\x86\x85å¿\x83ï¼\x8cå°±æ\x98¯æ\x83\x8aè\x89³ç\x9a\x84é£\x8eæ\x99¯', 'content': ['ä�
#     "flight_info": "支持航班变更调整",
#     "included_fees": [
#       "交通",
#       "住宿",
#       "餐食",
#       "景点门票"
#     ],
#     "excluded_fees": [
#       "私人消费",
#       "旅游保险"
#     ],
#     "notes": "建议提前3-5天报名",
#     "product_manager_speech": {
#       "title": "游客深入文旅行",
#       "description": "那些旅行中探知到的鲜活文化，触达内心，就是惊艳的风景",
#       "content": [
#         "一个中国极美符号：婆源墅峰，秋季梯田花海，东方小布达拉宫，全年都有的晒秋场景，徽派建筑的代表，享受慢生活。",
#         "一个枕源：瑶里古镇，被群山环抱，草木幽深，小桥流水，禽鸟啼鸣，飞瀑流泉，素有“瓷之源、茶之乡、林之海”的美称。",
#         "一个市集：陶溪川夜市，陶艺家聚集交流创意之地。一方创意，一方欣赏，闲逛创意市集，有别于其他市集，是一件有趣的事。",
#         "一座楼：七彩瓷楼，由一位老人累蓄的6万多件瓷器打造，她给世人留下的这座楼，必将激励后来人。",
#         "一位老人：12岁入行，一生为陶艺投入。凭一己之力，打造了一座巍巍七彩瓷楼。这种坚持与追求，对陶瓷的情怀，令人感佩。",
#         "一座古宫：北看故宫，南访古宫。观摩世界上古老的制瓷生产线，在这里探索千年窑火之谜。"
#       ]
#     },
#     "activity_highlights": {
#       "title": "游侠人文",
#       "description": "在旅行中自然而然的了解当地文化",
#       "highlights": [
#         {
#           "name": "行程特别",
#           "description": "从群美乡村瑶源出发，穿越至陶瓷发源地秘境瑶里"
#         },
#         {
#           "name": "深度纯玩",
#           "description": "拒绝走马观花，一路行摄，串联江西的文化景观线"
#         },
#         {
#           "name": "小众体验",
#           "description": "古村定向寻味，集市淘宝，制瓷听瓷乐，品瓷瓷宴"
#         },
#         {
#           "name": "景观特别",
#           "description": "山水林海瑶里，小桥流水古镇，品味山野的桃花源"
#         },
#         {
#           "name": "璀璨人文",
#           "description": "从陶艺手艺人的视角，探索中国璀璨的制瓷文化"
#         },
#         {
#           "name": "舒适住宿",
#           "description": "全程舒适酒店+1晚瑶里古镇，享桃花源的安静生活"
#         },
#         {
#           "name": "特别呈现",
#           "description": "访一座七彩瓷楼和瓷楼奶奶，听听背后的故事"
#         },
#         {
#           "name": "深入当地",
#           "description": "深入当地，游侠客深度线路小组，亲测开发"
#         }
#       ]
#     },
#     "itinerary": [
#       {
#         "day": 1,
#         "title": "杭州婺源",
#         "highlight": "篁岭晒秋的壮观景观；俯瞰极美梯田；走进中国美丽乡村婺源，感受画里老家的宁静",
#         "activities": [
#           {
#             "time": "上午",
#             "description": "上午7:00-7:30在黄龙海鲜大排档集合出发（节假日提前1小时发车，以出团短信为准）一路上领队做活动介绍、队员介绍，互动游戏，一路充满笑声欢语。12:00点到达婺源午餐"
#           },
#           {
#             "time": "下午",
#             "description": "13:00，我们乘坐观光缆车（费用包含）进入【篁岭古村】，篁岭是人文的杰作，篁岭晒秋则是民俗的符号。数十栋古老徽派民居在百米落差的岭谷错落排布，家家凿窗采光，户户支架晒物。村民们用眺窗为画板，支架为画笔，晒匾为调色盘，春晒水笋、蕨菜；秋晒红辣椒、稻谷黄豆……就这样成就了一幅幅民俗风情杰作，一年四季延绵有序。民居围绕水口呈扇形梯状错落排布，U形村落带您体验南方的“布达拉宫”。徽式商铺林立，前店后坊，一幅流动的缩写版“清明上河图”。穿过古村，是中国极为壮观的梯田，走上玻璃索桥，我们还可以走下梯田，从另外一座索桥绕一环线回到古村。傍晚，前往县城安排入住。途中，一幅幅渔舟唱晚的唯美画面呈现在众游侠眼帘，黄昏的落日影像美得无法用言语表达。",
#             "车程": "280KM",
#             "用餐": "中午农家聚餐 AA，晚上自由用餐",
#             "住宿": "婺源县城 1 晚 标间或大床",
#             "备注": "篁岭古村游览方式为乘坐观光缆车上下，费用已包含；如遇排队人数过多，也可能采用景交车上山+缆车下山的形式。"
#           },
#           {
#             "time": "晚上",
#             "description": "享用特色餐【瓷宴】，之后安排行程去陶溪川夜市。陶溪川夜市是年轻人聚集的地方，有各种创意产品和陶瓷。"
#           }
#         ]
#       },
#       {
#         "day": 2,
#         "title": "婺源瑶里古镇",
#         "highlight": "婺源板凳长桥，放风筝、玩游戏；瑶里古镇寻味，做任务；放慢节奏，在“桃花源”感受乡村的慢节奏和安逸。",
#         "车程": "70KM",
#         "用餐": "早餐酒店包含，正餐自由用餐或聚餐AA",
#         "住宿": "瑶里古镇1晚住宿",
#         "备注": "瑶里古镇介绍：古名“窑里”，景德镇陶瓷发祥地。沿河错落有致地分布着数百幢明清古建筑，信步在古镇青石铺就的街巷中，会使您仿佛走进了明清社会的历史画卷。千百年来，这里依旧原味，被称为景德镇的桃花源。",
#         "activities": [
#           {
#             "time": "上午",
#             "description": "早上吃个舒心的早餐。集合出发，前往婺源水口，这里是《欢乐颂2》的拍摄地，淳朴自然，逛一下这里古老的山村，婺源板凳长桥，草地河滩，清新脱俗，没有一个人不喜欢这里。。带小孩的游侠们可以在这里放放游侠客的特制风筝，特别有亲近自然的感觉。穿越婺源，途径【菊径奇村】，暂停一下，爬到观景台，拍摄“圆形村落”菊径全景。12：00前后，抵达瑶里古镇，安排午餐、住宿。"
#           },
#           {
#             "time": "下午",
#             "description": "13:30-15:30，我们去登山健身吧。驱车前往【汪湖生态旅游区】，感受瑶里的“山之清、水之秀、林之美”。沿着山间小道穿行，绿树成荫，好不清凉。尤其到了南山瀑布，水量磅礴时，蔚为壮观。环线而下，踏上徽饶古道、穿过红军桥（复源桥），感叹沧桑百年。傍晚回到【瑶里古镇景区】，我们在此慢下节奏，拒绝走马观花，踏着石板老街，贴近古镇生活。为此，我们精心设计了一场有意思的古村寻味活动。让大家参与其中，体验古村的特色传统文化。组建探索小分队，分发任务书，深入古镇，开启我们的古村寻味之旅。"
#           },
#           {
#             "time": "晚上",
#             "description": "在瑶河边住下，感受乡村生活的慢节奏和安静。"
#           }
#         ]
#       },
#       {
#         "day": 3,
#         "title": "瑶里古镇 景德镇",
#         "highlight": "亮点： 结识一位87岁的瓷楼奶奶，听听她的故事，参观一座令人叹为观止的七彩瓷楼；走进一座古窑“博物馆”，听一段瓷乐，品尝全瓷宴",
#         "车程": "50KM",
#         "用餐": "早餐包含，正餐自由用餐或聚餐AA，晚餐品尝全瓷宴（费用包含）",
#         "住宿": "景德镇市区经济型酒店标间/大床",
#         "activities": [
#           {
#             "time": "上午",
#             "description": "山间小镇早晨，空气清新，可以早起在河边走走。9:00-10:30，前往瑶里传统南陶瓷主题园景区。参观瑶里古窑，了解古老的矿洞、矿洞和龙窑遗址等古代陶瓷生产遗迹。"
#           },
#           {
#             "time": "下午",
#             "description": "午餐后，前往七彩瓷楼，了解一位87岁老奶奶的瓷楼故事。参观景德镇古窑民俗博览区，了解古代制瓷生产线。"
#           }
#         ]
#       },
#       {
#         "day": 4,
#         "title": "景德镇 杭州",
#         "车程": "360KM",
#         "用餐": "早餐酒店包含，午餐自由用餐",
#         "备注": "御窑博物馆每周一闭馆，如遇闭馆，我们将调整景点游玩顺序：第三天游玩御窑博物馆，第四天游玩古窑民俗博览区",
#         "activities": [
#           {
#             "time": "上午",
#             "description": "早餐后，前往御窑博物馆，了解皇家瓷厂的历史和文化。"
#           },
#           {
#             "time": "下午",
#             "description": "午餐后，返回杭州。18:30前抵达市区解散。"
#           }
#         ],
#         "notes": "御窑博物馆每周一闭馆，如遇闭馆，将调整行程顺序。"
#       }
#     ]
#   }
# ]

# %%
# 将读取的数据转换为JSONLoader所需的格式
# 注意  ⚠️ 不能有 空格符号 \n
documents = JSONLoader(
    file_path='../../../file/yxk-list.json',
    jq_schema='.',
    text_content=False
).load()

# %%
len(documents)
documents
# Out:
# [Document(page_content="[{'title': '登峰造极·云中岭丨青青草原 高山草甸 强度可选', 'introduce': '高山牧场，牛羊成群，中转车上山，徒步2km即可到达牧场，4-10公里AB线（A线休闲，B线户外）', 'theme': '户外游-徒步登山', 'positive_comment_rate': '好评率：99.1%', 'tags': '线路，收费，周边，旅游产品，跟团游-一日游，1天', 'duration': '1天', 'departure_city': '成都 四川省', 'product_features': '熊猫之乡;云中牧场;高山草甸;遥望雪山', 'price': '100元起', 'the_best_travel_date': '7月份'}, {'title': '婺源景德镇4日 从古徽州到瓷都的发现之旅', 'introduce': '婺源篁岭 | 梯田古村晒秋，瑶里古镇 | 探寻千年秘密，新平瓷宫 | 致敬瓷楼奶奶，陶溪川夜市 | 趣味淘宝，御窑博物馆 | 打卡宝藏机位', 'theme': '深度人文-文化历史；休闲度假-懒人慢游；美景探索-游山玩水', 'positive_comment_rate': '好评率：20.1%', 'tags': '线路，收费，国内,旅游产品,跟团游-多日游,4天3晚', 'duration': '4天3晚', 'departure_city': '杭州', 'product_features': '小众深度体验；陶瓷文化之旅；文艺惊艳之旅；精选舒适酒店', 'price': '2180元起', 'the_best_travel_date': '10月份'}]", metadata={'source': '/Users/pangmengting/Documents/workspace/python-learning/file/yxk-list.json', 'seq_num': 1})]

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
splits = text_splitter.split_documents(documents)

# %%
print(len(splits))
# Out:
# 1

# %%
vectorstore = SupabaseVectorStore.from_documents(
    splits,
    embeddings,
    client=supabase,
    table_name="bge_small_vector",
    query_name="bge_small_match_documents",
)
# Out:
# 2024-07-03 18:19:48,863:INFO - HTTP Request: POST https://infrxrfaftyrxvkwvncf.supabase.co/rest/v1/bge_small_vector?columns=%22id%22%2C%22metadata%22%2C%22content%22%2C%22embedding%22 "HTTP/1.1 201 Created"
