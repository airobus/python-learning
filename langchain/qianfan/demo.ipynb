# %%
##Installing the langchain packages needed to use the integration
# !pip install -qU langchain-community
# !pip install qianfan
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Collecting qianfan
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/18/ad/e7750d1aa608ae3632c62d3304849004285ec9c481de18d9b54bcdc8894b/qianfan-0.3.16-py3-none-any.whl (419 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 419.3/419.3 kB 366.6 kB/s eta 0:00:0000:0100:01
# Requirement already satisfied: aiohttp>=3.7.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (3.8.4)
# Collecting aiolimiter>=1.1.0 (from qianfan)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/60/69/4b7dea755fafa10b248928da836a2cc8b5cff0762f363234e24218040f8e/aiolimiter-1.1.0-py3-none-any.whl (7.2 kB)
# Collecting bce-python-sdk>=0.8.79 (from qianfan)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ec/7d/097355c40adb154de67548b35046391240cfbb6e9b64240b65234e804de4/bce_python_sdk-0.9.14-py3-none-any.whl (342 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 342.9/342.9 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Collecting diskcache<6.0.0,>=5.6.3 (from qianfan)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/3f/27/4570e78fc0bf5ea0ca45eb1de3818a23787af9b390c0b0a0033a1b8236f9/diskcache-5.6.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.5/45.5 kB 1.9 MB/s eta 0:00:00
# Requirement already satisfied: multiprocess in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (0.70.15)
# Requirement already satisfied: prompt-toolkit>=3.0.38 in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (3.0.39)
# Requirement already satisfied: pydantic in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (2.6.4)
# Requirement already satisfied: python-dotenv>=1.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (1.0.0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.1 in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (6.0.1)
# Requirement already satisfied: requests>=2.24 in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (2.31.0)
# Requirement already satisfied: rich>=13.0.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (13.4.2)
# Requirement already satisfied: tenacity<9.0.0,>=8.2.3 in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (8.2.3)
# Requirement already satisfied: typer>=0.9.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from qianfan) (0.9.0)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from aiohttp>=3.7.0->qianfan) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from aiohttp>=3.7.0->qianfan) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/pangmengting/venv/lib/python3.10/site-packages (from aiohttp>=3.7.0->qianfan) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/pangmengting/venv/lib/python3.10/site-packages (from aiohttp>=3.7.0->qianfan) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from aiohttp>=3.7.0->qianfan) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/pangmengting/venv/lib/python3.10/site-packages (from aiohttp>=3.7.0->qianfan) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/pangmengting/venv/lib/python3.10/site-packages (from aiohttp>=3.7.0->qianfan) (1.3.1)
# Collecting pycryptodome>=3.8.0 (from bce-python-sdk>=0.8.79->qianfan)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/ff/96/b0d494defb3346378086848a8ece5ddfd138a66c4a05e038fca873b2518c/pycryptodome-3.20.0-cp35-abi3-macosx_10_9_universal2.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 2.0 MB/s eta 0:00:00a 0:00:01
# Collecting future>=0.6.0 (from bce-python-sdk>=0.8.79->qianfan)
#   Downloading https://pypi.tuna.tsinghua.edu.cn/packages/da/71/ae30dadffc90b9006d77af76b393cb9dfbfc9629f339fc1574a1c52e6806/future-1.0.0-py3-none-any.whl (491 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.3/491.3 kB 1.2 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.4.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from bce-python-sdk>=0.8.79->qianfan) (1.16.0)
# Requirement already satisfied: wcwidth in /Users/pangmengting/venv/lib/python3.10/site-packages (from prompt-toolkit>=3.0.38->qianfan) (0.2.6)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pangmengting/venv/lib/python3.10/site-packages (from requests>=2.24->qianfan) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/pangmengting/venv/lib/python3.10/site-packages (from requests>=2.24->qianfan) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pangmengting/venv/lib/python3.10/site-packages (from requests>=2.24->qianfan) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from rich>=13.0.0->qianfan) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from rich>=13.0.0->qianfan) (2.15.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/pangmengting/venv/lib/python3.10/site-packages (from typer>=0.9.0->qianfan) (8.1.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/pangmengting/venv/lib/python3.10/site-packages (from typer>=0.9.0->qianfan) (4.10.0)
# Requirement already satisfied: dill>=0.3.7 in /Users/pangmengting/venv/lib/python3.10/site-packages (from multiprocess->qianfan) (0.3.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/pangmengting/venv/lib/python3.10/site-packages (from pydantic->qianfan) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Users/pangmengting/venv/lib/python3.10/site-packages (from pydantic->qianfan) (2.16.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/pangmengting/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich>=13.0.0->qianfan) (0.1.2)
# Installing collected packages: pycryptodome, future, diskcache, aiolimiter, bce-python-sdk, qianfan
#   Attempting uninstall: diskcache
#     Found existing installation: diskcache 5.6.1
#     Uninstalling diskcache-5.6.1:
#       Successfully uninstalled diskcache-5.6.1
# Successfully installed aiolimiter-1.1.0 bce-python-sdk-0.9.14 diskcache-5.6.3 future-1.0.0 pycryptodome-3.20.0 qianfan-0.3.16

# %%
"""For basic init and call"""
import os
from dotenv import load_dotenv
from langchain_community.llms.baidu_qianfan_endpoint import QianfanLLMEndpoint

load_dotenv(override=True)
QIANFAN_AK = os.getenv('QIANFAN_AK')
QIANFAN_SK = os.getenv('QIANFAN_SK')

print(QIANFAN_AK, QIANFAN_SK)

llm = QianfanLLMEndpoint(streaming=True)
res = llm.invoke("hi")
print(res)
# Out:
# p9JrW3lQ2DVmDI49FFTdDgd7 FaVH63jj41NejcI2eqflqdBwTgrK3OhY
# [ERROR][2024-06-17 09:49:15.926] openapi_requestor.py:258 [t:8062983872]: api request req_id:  failed with error code: 17, err msg: Open api daily request limit reached 可能的原因: 未开通所调用服务的付费权限，或者账户已欠费, please check https://cloud.baidu.com/doc/WENXINWORKSHOP/s/tlmyncueh
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# Cell In[6], line 13
#      10 print(QIANFAN_AK, QIANFAN_SK)
#      12 llm = QianfanLLMEndpoint(streaming=True)
# ---> 13 res = llm.invoke("hi")
#      14 print(res)
#
# File ~/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:276, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     266 def invoke(
#     267     self,
#     268     input: LanguageModelInput,
#    (...)
#     272     **kwargs: Any,
#     273 ) -> str:
#     274     config = ensure_config(config)
#     275     return (
# --> 276         self.generate_prompt(
#     277             [self._convert_input(input)],
#     278             stop=stop,
#     279             callbacks=config.get("callbacks"),
#     280             tags=config.get("tags"),
#     281             metadata=config.get("metadata"),
#     282             run_name=config.get("run_name"),
#     283             run_id=config.pop("run_id", None),
#     284             **kwargs,
#     285         )
#     286         .generations[0][0]
#     287         .text
#     288     )
#
# File ~/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:633, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     625 def generate_prompt(
#     626     self,
#     627     prompts: List[PromptValue],
#    (...)
#     630     **kwargs: Any,
#     631 ) -> LLMResult:
#     632     prompt_strings = [p.to_string() for p in prompts]
# --> 633     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:803, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     788 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     789     run_managers = [
#     790         callback_manager.on_llm_start(
#     791             dumpd(self),
#    (...)
#     801         )
#     802     ]
# --> 803     output = self._generate_helper(
#     804         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805     )
#     806     return output
#     807 if len(missing_prompts) > 0:
#
# File ~/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:670, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668     for run_manager in run_managers:
#     669         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670     raise e
#     671 flattened_outputs = output.flatten()
#     672 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File ~/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:657, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     647 def _generate_helper(
#     648     self,
#     649     prompts: List[str],
#    (...)
#     653     **kwargs: Any,
#     654 ) -> LLMResult:
#     655     try:
#     656         output = (
# --> 657             self._generate(
#     658                 prompts,
#     659                 stop=stop,
#     660                 # TODO: support multiple run managers
#     661                 run_manager=run_managers[0] if run_managers else None,
#     662                 **kwargs,
#     663             )
#     664             if new_arg_supported
#     665             else self._generate(prompts, stop=stop)
#     666         )
#     667     except BaseException as e:
#     668         for run_manager in run_managers:
#
# File ~/venv/lib/python3.10/site-packages/langchain_core/language_models/llms.py:1317, in LLM._generate(self, prompts, stop, run_manager, **kwargs)
#    1314 new_arg_supported = inspect.signature(self._call).parameters.get("run_manager")
#    1315 for prompt in prompts:
#    1316     text = (
# -> 1317         self._call(prompt, stop=stop, run_manager=run_manager, **kwargs)
#    1318         if new_arg_supported
#    1319         else self._call(prompt, stop=stop, **kwargs)
#    1320     )
#    1321     generations.append([Generation(text=text)])
#    1322 return LLMResult(generations=generations)
#
# File ~/venv/lib/python3.10/site-packages/langchain_community/llms/baidu_qianfan_endpoint.py:179, in QianfanLLMEndpoint._call(self, prompt, stop, run_manager, **kwargs)
#     177 if self.streaming:
#     178     completion = ""
# --> 179     for chunk in self._stream(prompt, stop, run_manager, **kwargs):
#     180         completion += chunk.text
#     181     return completion
#
# File ~/venv/lib/python3.10/site-packages/langchain_community/llms/baidu_qianfan_endpoint.py:216, in QianfanLLMEndpoint._stream(self, prompt, stop, run_manager, **kwargs)
#     214 params = self._convert_prompt_msg_params(prompt, **{**kwargs, "stream": True})
#     215 params["stop"] = stop
# --> 216 for res in self.client.do(**params):
#     217     if res:
#     218         chunk = GenerationChunk(text=res["result"])
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/llm/completion.py:202, in Completion.do(self, prompt, model, endpoint, stream, retry_count, request_timeout, request_id, backoff_factor, **kwargs)
#     199 if request_id is not None:
#     200     kwargs["request_id"] = request_id
# --> 202 return self._do(
#     203     model,
#     204     stream,
#     205     retry_count,
#     206     request_timeout,
#     207     backoff_factor,
#     208     endpoint=endpoint,
#     209     **kwargs,
#     210 )
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/llm/base.py:542, in BaseResource._do(self, model, stream, retry_count, request_timeout, backoff_factor, retry_jitter, retry_err_codes, retry_max_wait_interval, **kwargs)
#     526 """
#     527 qianfan resource basic do
#     528
#    (...)
#     531
#     532 """
#     533 retry_config = self.generate_retry_config(
#     534     retry_count=retry_count,
#     535     request_timeout=request_timeout,
#    (...)
#     539     retry_max_wait_interval=retry_max_wait_interval,
#     540 )
# --> 542 return self._request(model, stream, retry_config, **kwargs)
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/llm/base.py:679, in BaseResourceV1._request(self, model, stream, retry_config, **kwargs)
#     677             continue
#     678         else:
# --> 679             raise e
#     680     break
#     682 return resp
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/llm/base.py:660, in BaseResourceV1._request(self, model, stream, retry_config, **kwargs)
#     658 while True:
#     659     try:
# --> 660         resp = self._client.llm(
#     661             endpoint=endpoint,
#     662             header=self._generate_header(model, stream, **kwargs),
#     663             query=self._generate_query(model, stream, **kwargs),
#     664             body=self._generate_body(model, stream, **kwargs),
#     665             stream=stream,
#     666             data_postprocess=self._data_postprocess,
#     667             retry_config=retry_config,
#     668         )
#     669     except errors.APIError as e:
#     670         if (
#     671             e.error_code == APIErrorCode.UnsupportedMethod
#     672             and not refreshed_model_list
#     673         ):
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/requestor/openapi_requestor.py:427, in QfAPIRequestor.llm(self, endpoint, header, query, body, stream, data_postprocess, retry_config)
#     418     else:
#     419         return self._compensate_token_usage_non_stream(
#     420             self._request(
#     421                 req,
#    (...)
#     424             token_count,
#     425         )
# --> 427 return self._with_retry(retry_config, _helper)
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/requestor/base.py:427, in BaseAPIRequestor._with_retry(self, config, func, *args)
#     414 @retry(
#     415     wait=wait_exponential_jitter(
#     416         initial=config.backoff_factor,
#    (...)
#     423 )
#     424 def _retry_wrapper(*args: Any) -> _T:
#     425     return func(*args)
# --> 427 return _retry_wrapper(*args)
#
# File ~/venv/lib/python3.10/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~/venv/lib/python3.10/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~/venv/lib/python3.10/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/venv/lib/python3.10/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/requestor/base.py:425, in BaseAPIRequestor._with_retry.<locals>._retry_wrapper(*args)
#     414 @retry(
#     415     wait=wait_exponential_jitter(
#     416         initial=config.backoff_factor,
#    (...)
#     423 )
#     424 def _retry_wrapper(*args: Any) -> _T:
# --> 425     return func(*args)
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/requestor/openapi_requestor.py:80, in QfAPIRequestor._retry_if_token_expired.<locals>.retry_wrapper(*args, **kwargs)
#      78 if not token_refreshed:
#      79     try:
# ---> 80         return func(*args)
#      81     except errors.AccessTokenExpiredError:
#      82         # refresh token and set token_refreshed flag
#      83         self._auth.refresh_access_token()
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/requestor/openapi_requestor.py:415, in QfAPIRequestor.llm.<locals>._helper()
#     411 self._token_limiter.decline(token_count)
#     413 if stream:
#     414     return self._compensate_token_usage_stream(
# --> 415         self._request_stream(req, data_postprocess=data_postprocess),
#     416         token_count,
#     417     )
#     418 else:
#     419     return self._compensate_token_usage_non_stream(
#     420         self._request(
#     421             req,
#    (...)
#     424         token_count,
#     425     )
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/requestor/base.py:219, in _stream_latency.<locals>.wrapper(requestor, request, *args, **kwargs)
#     217 with requestor._rate_limiter:
#     218     start_time = time.perf_counter()
# --> 219     resp = func(requestor, request, *args, **kwargs)
#     221 def iter() -> Iterator[QfResponse]:
#     222     is_first_block = True
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/requestor/openapi_requestor.py:105, in QfAPIRequestor._request_stream(self, request, data_postprocess)
#     103 if "json" in resp.headers.get("content-type", ""):
#     104     body, resp = next(responses)
# --> 105     self._check_error(json.loads(body))
#     107 def iter() -> Iterator[QfResponse]:
#     108     event = ""
#
# File ~/venv/lib/python3.10/site-packages/qianfan/resources/requestor/openapi_requestor.py:268, in QfAPIRequestor._check_error(self, body)
#     263 if error_code in {
#     264     APIErrorCode.APITokenExpired.value,
#     265     APIErrorCode.APITokenInvalid.value,
#     266 }:
#     267     raise errors.AccessTokenExpiredError
# --> 268 raise errors.APIError(error_code, err_msg, req_id)
#
# APIError: api return error, req_id:  code: 17, msg: Open api daily request limit reached 可能的原因: 未开通所调用服务的付费权限，或者账户已欠费
